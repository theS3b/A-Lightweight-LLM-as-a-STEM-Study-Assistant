# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls
# %cd drive/MyDrive
# Out:
# drive/  sample_data/
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ahuou/lighteval-epfl-mnlp.git
# Out:
# Cloning into 'lighteval-epfl-mnlp'...
# remote: Enumerating objects: 4002, done.
# remote: Counting objects: 100% (1351/1351), done.
# remote: Compressing objects: 100% (330/330), done.
# remote: Total 4002 (delta 1196), reused 1024 (delta 1020), pack-reused 2651 (from 4)
# Receiving objects: 100% (4002/4002), 1.90 MiB | 15.56 MiB/s, done.
# Resolving deltas: 100% (2546/2546), done.
# Filtering content: 100% (2/2), 65.44 MiB | 16.99 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/lighteval-epfl-mnlp/.git/hooks/post-checkout': Permission denied

# %%
# %cd lighteval-epfl-mnlp/
# Out:
# /content/drive/MyDrive/lighteval-epfl-mnlp

# %%
# !git checkout feature/faiss-index-caching
# Out:
# Branch 'feature/faiss-index-caching' set up to track remote branch 'feature/faiss-index-caching' from 'origin'.
# Switched to a new branch 'feature/faiss-index-caching'
# fatal: cannot exec '.git/hooks/post-checkout': Permission denied

# %%
# !pip install -e .[quantization]
# Out:
# Obtaining file:///content/drive/MyDrive/lighteval-epfl-mnlp
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 17.2 MB/s eta 0:00:00
# ...

# %%
# %ls
# Out:
# assets/           faiss_cache/  MANIFEST.in     README.md  tests/
# community_tasks/  LICENSE       model_configs/  setup.py
# COMPUTE.md        Makefile      pyproject.toml  src/

# %%
# %cd ../../..
# Out:
# /content

# %%
# !pip install transformers==4.51.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 104.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `mnlp` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...

# %%
# %cd drive/MyDrive/lighteval-epfl-mnlp/
# Out:
# /content/drive/MyDrive/lighteval-epfl-mnlp

# %%
# %ls
# Out:
# assets/           faiss_cache/  MANIFEST.in     README.md  tests/
# community_tasks/  LICENSE       model_configs/  setup.py
# COMPUTE.md        Makefile      pyproject.toml  src/

# %%
# !lighteval accelerate \
    --eval-mode "rag" \
    --save-details \
    --override-batch-size 4 \
    --custom-tasks "community_tasks/mnlp_mcqa_evals.py" \
    --output-dir "../MNLP_output" \
    model_configs/rag_model.yaml \
    "community|mnlp_mcqa_evals|0|0"
# Out:
# Streaming output truncated to the last 5000 lines.
# [2025-06-11 09:43:56,883] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3941 || 7848 (pipeline.py:543)
# [2025-06-11 09:43:56,906] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3942 || 7848 (pipeline.py:543)
# [2025-06-11 09:43:56,929] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3943 || 7848 (pipeline.py:543)
# [2025-06-11 09:43:56,952] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3944 || 7848 (pipeline.py:543)
# [2025-06-11 09:43:56,975] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3945 || 7848 (pipeline.py:543)
# [2025-06-11 09:43:56,998] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3946 || 7848 (pipeline.py:543)
# [2025-06-11 09:43:57,021] [    INFO]: Retrieving documents for RequestType.LOGLIKELIHOOD request 3947 || 7848 (pipeline.py:543)
# ...
